# %%
import shapely
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import numpy as np
import elevation

import pymagery
from pymagery import utils
from pymagery import context
import aoi

# %%
dem_path = context.dem_data_dir + '/dem.tif'
elevation.clip(bounds=aoi.bounds, output=dem_path, product='SRTM1')

# %%
# test

fig, ax = plt.subplots(figsize=(16, 16))
dem = pymagery.SingleBand.from_path(dem_path)
dem.plot(ax=ax, hs=True)
# Out:
# (None, <AxesSubplot:>)
